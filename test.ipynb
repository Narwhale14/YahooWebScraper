# %%
import requests
from bs4 import BeautifulSoup
URL = "https://finance.yahoo.com/markets/world-indices/"
headers = {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/51.0.2704.103 Safari/537.36', 'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8'}
page = requests.get(URL, headers=headers)

# %%
print(page)
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content, "html.parser")
rows = soup.find_all("tr", class_="row")

for row in rows:
    symbol = row.find("span", class_="symbol").get_text(strip=True)[1:]
    name = row.find("div", class_="companyName").get_text(strip=True)
    price = row.find("fin-streamer", attrs={"data-field": "regularMarketPrice"}).get_text(strip=True)
    print(name, symbol, price)
# Out:
# S&P 500 GSPC 6,771.55
# Dow Jones Industrial Average DJI 47,085.24
# NASDAQ Composite IXIC 23,348.64
# NYSE Composite Index NYA 21,282.71
# NYSE American Composite Index XAX 6,787.69
# Cboe UK 100 BUK100P 968.61
# Russell 2000 Index RUT 2,427.34
# CBOE Volatility Index VIX 19.00
# FTSE 100 FTSE 9,714.96
# DAX P GDAXI 23,949.11
# CAC 40 FCHI 8,067.53
# EURO STOXX 50                 I STOXX50E 5,660.20
# Euronext 100 Index N100 1,705.93
# BEL 20 BFX 4,920.87
# Public Joint-Stock Company Moscow Exchange MICEX-RTS OEX.ME 85.20
# HANG SENG INDEX HSI 25,952.40
# STI Index STI 4,422.72
# S&P/ASX 200 AXJO 8,791.40
# ALL ORDINARIES AORD 9,059.80
# S&P BSE SENSEX BSESN 83,459.15
# IDX COMPOSITE JKSE 8,241.91
# FTSE Bursa Malaysia KLCI KLSE 1,623.50
# S&P/NZX 50 INDEX GROSS ( GROSS NZ50 13,548.95
# KOSPI Composite Index KS11 4,121.74
# TWSE Capitalization Weighted Stock Index TWII 28,116.56
# S&P/TSX Composite index GSPTSE 29,777.82
# IBOVESPA BVSP 150,704.20
# IPC MEXICO MXX 62,390.73
# ...
